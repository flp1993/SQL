# %% [markdown]
# # Limpeza e Processamento de Dados

# %% [markdown]
# ## 1. Importacoes e Carga:

# %%
# Importando Bibliotecas
import pandas as pd
import sqlite3 as sq3

# %%
# Carregando os arquivos CSV em Dataframes
DF_Mortes = pd.read_csv("Dataset/covid_mortes.csv")
DF_Vacinas = pd.read_csv("Dataset/covid_vacinacao.csv")

# %%
DF_Mortes.head()
# Out:
#   iso_code continent     location      date  population  total_cases  \
# 0      AFG      Asia  Afghanistan  24/02/20  38928341.0          1.0
# 1      AFG      Asia  Afghanistan  25/02/20  38928341.0          1.0
# 2      AFG      Asia  Afghanistan  26/02/20  38928341.0          1.0
# 3      AFG      Asia  Afghanistan  27/02/20  38928341.0          1.0
# 4      AFG      Asia  Afghanistan  28/02/20  38928341.0          1.0
#
#    new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 0        1.0                 NaN           NaN         NaN  ...
# 1        0.0                 NaN           NaN         NaN  ...
# 2        0.0                 NaN           NaN         NaN  ...
# 3        0.0                 NaN           NaN         NaN  ...
# 4        0.0                 NaN           NaN         NaN  ...
#
#    new_deaths_smoothed_per_million  reproduction_rate  icu_patients  \
# 0                              NaN                NaN           NaN
# ...

# %%
DF_Mortes.shape
# Out:
# (100181, 26)

# %%
DF_Vacinas.head()
# Out:
#   iso_code continent     location      date  new_tests  total_tests  \
# 0      AFG      Asia  Afghanistan  24/02/20        NaN          NaN
# 1      AFG      Asia  Afghanistan  25/02/20        NaN          NaN
# 2      AFG      Asia  Afghanistan  26/02/20        NaN          NaN
# 3      AFG      Asia  Afghanistan  27/02/20        NaN          NaN
# 4      AFG      Asia  Afghanistan  28/02/20        NaN          NaN
#
#    total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN                 NaN
# 2                       NaN                     NaN                 NaN
# 3                       NaN                     NaN                 NaN
# 4                       NaN                     NaN                 NaN
#
#    new_tests_smoothed_per_thousand  ...  extreme_poverty  \
# 0                              NaN  ...              NaN
# ...

# %%
DF_Vacinas.shape
# Out:
# (100181, 38)

# %% [markdown]
# ### -  1.1 Criacao do Banco e Carga de Dados

# %%
# Crianco Banco de Dados 
CovidDB = sq3.connect("Database/Covid.db")

# %%
# Carregando 2 DataFrames em tabelas diferentes
DF_Mortes.to_sql("Mortes",CovidDB)
DF_Vacinas.to_sql("Vacinas",CovidDB)
# Out:
# 100181

# %% [markdown]
# ### -  1.2 Consultas ao Banco

# %%
# Carregando a extensao "SQl" para permitir consultas ao Banco de Dados
# %load_ext sql

# %%
# Montando conexao com o Banco criado
# %sql sqlite:///Database/Covid.db

# %%
# %%sql
#
# SELECT *
# FROM MORTES
# LIMIT 10
# Out:
#  * sqlite:///Database/Covid.db
# Done.
# [(0, 'AFG', 'Asia', 'Afghanistan', '24/02/20', 38928341.0, 1.0, 1.0, None, None, None, None, 0.026, 0.026, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  (1, 'AFG', 'Asia', 'Afghanistan', '25/02/20', 38928341.0, 1.0, 0.0, None, None, None, None, 0.026, 0.0, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  (2, 'AFG', 'Asia', 'Afghanistan', '26/02/20', 38928341.0, 1.0, 0.0, None, None, None, None, 0.026, 0.0, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  (3, 'AFG', 'Asia', 'Afghanistan', '27/02/20', 38928341.0, 1.0, 0.0, None, None, None, None, 0.026, 0.0, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  (4, 'AFG', 'Asia', 'Afghanistan', '28/02/20', 38928341.0, 1.0, 0.0, None, None, None, None, 0.026, 0.0, None, None, None, None, None, None, None, None, None, None, None, None, None),
# ...

# %%
# %%sql
#
# SELECT *
# FROM VACINAS
# LIMIT 10
# Out:
#  * sqlite:///Database/Covid.db
# Done.
# [(0, 'AFG', 'Asia', 'Afghanistan', '24/02/20', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 8.33, 54.422, 18.6, 2.581, 1.337, 1803.987, None, 597.029, 9.59, None, None, 37.746, 0.5, 64.83, 0.511, None),
#  (1, 'AFG', 'Asia', 'Afghanistan', '25/02/20', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 8.33, 54.422, 18.6, 2.581, 1.337, 1803.987, None, 597.029, 9.59, None, None, 37.746, 0.5, 64.83, 0.511, None),
#  (2, 'AFG', 'Asia', 'Afghanistan', '26/02/20', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 8.33, 54.422, 18.6, 2.581, 1.337, 1803.987, None, 597.029, 9.59, None, None, 37.746, 0.5, 64.83, 0.511, None),
# ...

# %% [markdown]
# ## 2. Limpeza de Dados:

# %% [markdown]
# ### -  2.1 Tratando Valores Ausentes

# %% [markdown]
# ### -  2.2 Detectando/Tratando Outliers

# %% [markdown]
# ### -  2.3 Detectando/Tratando Registros Duplicados

# %% [markdown]
# ### -  2.4 Reorganizando Dados

# %% [markdown]
# ## 3. Processando Dados:

# %% [markdown]
# ### -  3.1 Traformacao de Atributos (Parsing)

# %% [markdown]
# ### -  3.2 Mapeamento

# %% [markdown]
# ### -  3.3 Filtragem Agregacao e Sumarizacao

# %% [markdown]
# ### -  3.4 Enriquecimento e Imputacao de Dados
